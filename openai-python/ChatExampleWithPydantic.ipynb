# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 1.2 MB/s eta 0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 3.0 MB/s eta 0:00:000:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.2/808.2 kB 3.5 MB/s eta 0:00:003.5 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 3.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 1.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.0/380.0 kB 2.7 MB/s eta 0:00:002.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 2.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 3.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 2.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import os

from gpt_pydantic import OpenAI

# %%
os.environ["OPENAI_MODEL"] = "gpt-3.5-turbo"
os.environ["OPENAI_API_KEY"] = "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"

# %%
client = OpenAI()

# %%
name = "Charizard"
client.get_pokemon(name=name)
# Out:
# {'name': 'Charizard',
#  'japanese_name': 'リザードン',
#  'pokedex_number': '006',
#  'percentage_male': '88.1',
#  'type1': 'Fire',
#  'type2': 'Flying',
#  'classification': 'Flame Pokémon',
#  'height_m': '1.7',
#  'weight_kg': '90.5',
#  'capture_rate': '45',
#  'base_egg_steps': '5120',
#  'abilities': 'Blaze,Solar Power',
#  'experience_growth': '1,059,860',
#  'base_happiness': '70',
#  'against_': 'Fire,Water,Electric,Grass,Ice,Fighting,Ground',
#  'hp': '78',
#  'attack': '84',
#  'defense': '78',
#  'sp_attack': '109',
#  'sp_defense': '85',
#  'speed': '100',
#  'generation': 'Generation I',
#  'is_legendary': '0'}
